# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data ={
    "Price":[20,25,30,35,40],
    "Bottles Sold":[120,110,90,80,70] }
df = pd.DataFrame(data)

# %%
df
# Out:
#    Price  Bottles Sold
# 0     20           120
# 1     25           110
# 2     30            90
# 3     35            80
# 4     40            70

# %%
df["Revenue"] = df["Price"]* df["Bottles Sold"]

# %%
df
# Out:
#    Price  Bottles Sold  Revenue
# 0     20           120     2400
# 1     25           110     2750
# 2     30            90     2700
# 3     35            80     2800
# 4     40            70     2800

# %%
highest_rev = df["Revenue"].max()
price = df.loc[df["Revenue"]==highest_revenue, "Price"]
print("The Highest Revenue:", highest_rev)
print("The prices that generated the highest revenue are:")
print(price.tolist())
# Out:
# The Highest Revenue: 2800
# The prices that generated the highest revenue are:
# [35, 40]

# %%
plt.bar(df["Price"], df["Revenue"], color= "pink")

plt.title("Price vs Revenue")
plt.xlabel("Price (₹)")
plt.ylabel("Revenue (₹)")

plt.show()

# %%
print("The analysis shows that the highest revenue is ₹2800.")
print("Although both ₹35 and ₹40 earn the same revenue, ₹35 results in higher sales volume.")
print("Therefore, ₹35 is the better selling price for maximizing revenue while attracting more customers.")
# Out:
# The analysis shows that the highest revenue is ₹2800.
# Although both ₹35 and ₹40 earn the same revenue, ₹35 results in higher sales volume.
# Therefore, ₹35 is the better selling price for maximizing revenue while attracting more customers.
